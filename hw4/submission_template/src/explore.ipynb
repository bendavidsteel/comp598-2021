# %%
import os
import pandas as pd

# %%
dataset_path = os.path.join('/', 'home', 'ben', 'projects', 'comp598-2021', 'hw4', 'submission_template', 'data', 'nyc_311_limit_2020.csv')
df = pd.read_csv(dataset_path, 
                 names=['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name', 'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip', 'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2', 'Intersection Street 1', 'Intersection Street 2', 'Address Type', 'City', 'Landmark', 'Facility Type', 'Status', 'Due Date', 'Resolution Description', 'Resolution Action Updated Date', 'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)', 'Y Coordinate (State Plane)', 'Open Data Channel Type', 'Park Facility Name', 'Park Borough', 'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment', 'Latitude', 'Longitude', 'Location'],
                 dtype={'Incident Zip': 'str'})
df.head()
# Out:
# /home/ben/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (18,20,31,32,33,34,35,36,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unique Key            Created Date             Closed Date Agency  \
# 0    40990189  11/20/2018 06:15:00 AM  05/21/2020 03:00:00 AM    DEP
# 1    40990529  11/20/2018 08:29:45 PM  01/13/2020 11:59:10 AM  DOHMH
# 2    40990691  11/20/2018 11:27:17 AM  04/03/2020 10:05:38 AM    DPR
# 3    40992202  11/20/2018 05:33:24 PM  02/08/2020 12:32:19 PM    DPR
# 4    40992582  11/20/2018 10:00:20 PM  04/15/2020 01:12:36 PM    HPD
#
#                                          Agency Name           Complaint Type  \
# 0             Department of Environmental Protection                    Sewer
# 1            Department of Health and Mental Hygiene                 Day Care
# 2                 Department of Parks and Recreation             Damaged Tree
# 3                 Department of Parks and Recreation  Overgrown Tree/Branches
# 4  Department of Housing Preservation and Develop...                  GENERAL
#
#                                Descriptor         Location Type Incident Zip  \
# 0  Manhole Cover Broken/Making Noise (SB)                   NaN        11385
# 1                                   Other   Commercial Building        10039
# 2             Entire Tree Has Fallen Down                Street        11230
# 3                         Blocking Street                Street        11249
# 4                             COOKING GAS  RESIDENTIAL BUILDING        10040
#
#       Incident Address  ... Vehicle Type Taxi Company Borough  \
# 0                  NaN  ...          NaN                  NaN
# 1  258 WEST 153 STREET  ...          NaN                  NaN
# 2    948 EAST 7 STREET  ...          NaN                  NaN
# 3     103 BERRY STREET  ...          NaN                  NaN
# 4   25 HILLSIDE AVENUE  ...          NaN                  NaN
#
#   Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction  \
# 0                   NaN                 NaN                      NaN
# 1                   NaN                 NaN                      NaN
# 2                   NaN                 NaN                      NaN
# 3                   NaN                 NaN                      NaN
# 4                   NaN                 NaN                      NaN
#
#   Road Ramp Bridge Highway Segment   Latitude  Longitude  \
# 0       NaN                    NaN  40.698139 -73.891106
# 1       NaN                    NaN  40.827390 -73.937135
# 2       NaN                    NaN  40.627659 -73.969739
# 3       NaN                    NaN  40.719101 -73.958496
# 4       NaN                    NaN  40.858698 -73.930020
#
#                     Location
# 0  (40.6981388, -73.8911062)
# 1  (40.8273901, -73.9371348)
# 2  (40.6276592, -73.9697386)
# 3  (40.7191006, -73.9584959)
# 4  (40.8586976, -73.9300197)
#
# [5 rows x 41 columns]

# %%
df['Incident Zip'][df['Incident Zip'].notna()].unique()
#print([str(int(zip_code)) for zip_code in df['Incident Zip'].notna()])
# Out:
# array(['11385', '10039', '11230', '11249', '10040', '11434', '11368',
#        '10304', '10014', '11422', '11101', '11418', '11217', '10037',
#        '11432', '11377', '11234', '11218', '11414', '10472', '10454',
#        '10036', '11236', '11419', '11206', '11102', '10001', '11203',
#        '11367', '11232', '10029', '11228', '11423', '11226', '10459',
#        '11238', '11355', '11364', '11360', '11357', '10003', '10453',
#        '11361', '11213', '10463', '10467', '10473', '11204', '11222',
#        '10027', '11210', '10466', '10016', '11220', '11233', '11201',
#        '11417', '11435', '11415', '10314', '11105', '10025', '10282',
#        '10469', '11354', '10065', '11209', '10452', '11004', '11214',
#        '11369', '11221', '11429', '10032', '11421', '11427', '11378',
#        '11211', '11370', '10031', '10038', '11420', '10457', '11237',
#        '11208', '10303', '10033', '11373', '11216', '11411', '10462',
#        '10024', '10011', '11223', '11104', '10002', '10468', '11374',
#        '11225', '11372', '10022', '11362', '11229', '10017', '11207',
#        '11379', '10044', '11219', '11366', '11365', '10301', '11413',
#        '11412', '10019', '10009', '10306', '11103', '10458', '11106',
#        '10305', '10023', '10012', '10010', '11231', '11205', '10075',
#        '11001', '10013', '11212', '10312', '11375', '11433', '10465',
#        '11358', '10451', '10471', '10461', '10456', '11692', '11215',
#        '10460', '11694', '10021', '10035', '10128', '10004', '10168',
#        '11416', '11224', '10028', '11239', '11691', '10309', '10308',
#        '10034', '11235', '11426', '10475', '10455', '11693', '11428',
#        '10310', '11436', '10302', '11356', '10470', '10474', '10026',
#        '11109', '10464', '11363', '10018', '10030', '10005', '10007',
#        '10280', '10307', '10006', '11430', '11040', '10020', '10169',
#        '10121', '10041', '10111', '11697', '10069', '10162', '10281',
#        '10120', '10123', '10278', '10105', '10045', '10106', '10103',
#        '10165', '11005', '10000', '10122', '10118', '10173', '11359',
#        '10177', '10178', '12345', '10171', '10119', '10172', '10279',
#        '11695', '11371', '10151', '11242', '10154', '10152', '10271',
#        '10110', '10155', '10170', '10166', '10158', '10179', '11251',
#        '10055', '10112', '11241', '10107', '10176', '10115', '10174',
#        '00083', '10153', '10048', '10167', '10175', '07114', '20005',
#        '08542'], dtype=object)
